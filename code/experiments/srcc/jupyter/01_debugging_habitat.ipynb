# %%
# %pylab inline

# %load_ext autoreload
# %autoreload 2
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
import os

# %%
jupyter_dir = "/Users/mroberts/code/github/interiorsim/code/experiments/srcc/jupyter"

jupyter_dir
# Out:
# '/Users/mroberts/code/github/interiorsim/code/experiments/srcc/jupyter'

# %%
habitat_dir = "/Users/mroberts/code/github/habitat-lab"
os.chdir(habitat_dir)

# %%
import habitat

env = habitat.Env(
    config=habitat.get_config("configs/tasks/pointnav_gibson.yaml")
)
# Out:
# 2021-11-02 16:29:18,113 Initializing dataset PointNav-v1
# 2021-11-02 16:31:31,592 initializing sim Sim-v0
# WARNING: Logging before InitGoogleLogging() is written to STDERR
# I1102 16:31:31.597357 147127744 ManagedFileBasedContainer.h:210] <Dataset>::convertFilenameToPassedExt : Filename : default changed to proposed scene_dataset_config.json filename : default.scene_dataset_config.json
# I1102 16:31:31.598999 147127744 AttributesManagerBase.h:365] <Dataset>::createFromJsonOrDefaultInternal : Proposing JSON name : default.scene_dataset_config.json from original name : default | This file  does not exist.
# I1102 16:31:31.601886 147127744 AssetAttributesManager.cpp:120] Asset attributes (capsule3DSolid : capsule3DSolid_hemiRings_4_cylRings_1_segments_12_halfLen_0.75_useTexCoords_false_useTangents_false) created and registered.
# ...

# %%
observation = env.reset()
print(observation.keys())

imshow(observation["rgb"]);
# Out:
# dict_keys(['rgb', 'pointgoal_with_gps_compass'])

# %%
env.action_space
# Out:
# ActionSpace(MOVE_FORWARD:EmptySpace(), STOP:EmptySpace(), TURN_LEFT:EmptySpace(), TURN_RIGHT:EmptySpace())

# %%
observation = env.step("MOVE_FORWARD")
print(observation.keys())

imshow(observation["rgb"]);
# Out:
# dict_keys(['rgb', 'pointgoal_with_gps_compass'])

# %%
observation = env.step("TURN_LEFT")
print(observation.keys())

imshow(observation["rgb"]);
# Out:
# dict_keys(['rgb', 'pointgoal_with_gps_compass'])

# %%
observation = env.step("TURN_LEFT")
print(observation.keys())

imshow(observation["rgb"]);
# Out:
# dict_keys(['rgb', 'pointgoal_with_gps_compass'])

# %%
observation = env.step("TURN_LEFT")
print(observation.keys())

imshow(observation["rgb"]);
# Out:
# dict_keys(['rgb', 'pointgoal_with_gps_compass'])

# %%
config=habitat.get_config("configs/tasks/pointnav_gibson.yaml")

print(config)
# Out:
# DATASET:
#   CONTENT_SCENES: ['*']
#   DATA_PATH: data/datasets/pointnav/gibson/v1/{split}/{split}.json.gz
#   SCENES_DIR: data/scene_datasets
#   SPLIT: train
#   TYPE: PointNav-v1
# ENVIRONMENT:
#   ITERATOR_OPTIONS:
#     CYCLE: True
#     GROUP_BY_SCENE: True
#     MAX_SCENE_REPEAT_EPISODES: -1
#     MAX_SCENE_REPEAT_STEPS: 10000
#     NUM_EPISODE_SAMPLE: -1
#     SHUFFLE: True
#     STEP_REPETITION_RANGE: 0.2
#   MAX_EPISODE_SECONDS: 10000000
#   MAX_EPISODE_STEPS: 500
# PYROBOT:
#   BASE_CONTROLLER: proportional
#   BASE_PLANNER: none
#   BUMP_SENSOR:
#     TYPE: PyRobotBumpSensor
#   DEPTH_SENSOR:
#     CENTER_CROP: False
#     HEIGHT: 480
#     MAX_DEPTH: 5.0
#     MIN_DEPTH: 0.0
#     NORMALIZE_DEPTH: True
#     TYPE: PyRobotDepthSensor
#     WIDTH: 640
#   LOCOBOT:
#     ACTIONS: ['BASE_ACTIONS', 'CAMERA_ACTIONS']
#     BASE_ACTIONS: ['go_to_relative', 'go_to_absolute']
#     CAMERA_ACTIONS: ['set_pan', 'set_tilt', 'set_pan_tilt']
#   RGB_SENSOR:
#     CENTER_CROP: False
# ...
