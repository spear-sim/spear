# %%
import os
import pprint
import spear

# %%
# create instance
config = spear.get_config(user_config_files=[os.path.realpath("user_config.yaml")])
spear.configure_system(config=config)
instance = spear.Instance(config=config)
game = instance.get_game()
# Out:
# [SPEAR | instance.py:0074] __init__
# [SPEAR | instance.py:0079]     Creating instance with launch mode: game
# [SPEAR | instance.py:0087]     Game executable: /Users/miroberts/code/github/spear/cpp/unreal_projects/SpearSim/Standalone-Development/Mac/SpearSim.app
# [SPEAR | instance.py:0266]     _request_launch_unreal_instance
# [SPEAR | instance.py:0267]         Requesting to launch Unreal instance...
# [SPEAR | instance.py:0279]         Writing temp config file: /Users/miroberts/code/github/spear/examples/getting_started_notebook/tmp/config.yaml
# [SPEAR | instance.py:0371]         Attempting to launch executable: /Users/miroberts/code/github/spear/cpp/unreal_projects/SpearSim/Standalone-Development/Mac/SpearSim.app/Contents/MacOS/SpearSim
# [SPEAR | instance.py:0383]         Launching executable with the following command-line arguments:
# [SPEAR | instance.py:0384]             /Users/miroberts/code/github/spear/cpp/unreal_projects/SpearSim/Standalone-Development/Mac/SpearSim.app/Contents/MacOS/SpearSim
# [SPEAR | instance.py:0386]                 -resx=512
# [SPEAR | instance.py:0386]                 -resy=512
# [SPEAR | instance.py:0386]                 -graphicsadapter=0
# [SPEAR | instance.py:0386]                 -windowed
# [SPEAR | instance.py:0386]                 -nosound
# [SPEAR | instance.py:0386]                 -stdout
# [SPEAR | instance.py:0386]                 -fullstdoutlogoutput
# [SPEAR | instance.py:0386]                 -nologtimes
# [SPEAR | instance.py:0386]                 -config_file=/Users/miroberts/code/github/spear/examples/getting_started_notebook/tmp/config.yaml
# [SPEAR | instance.py:0387]         Launching executable with the following config values:
# SPEAR:
#   ENGINE_SERVICE:
#     PRINT_CALL_DEBUG_INFO: False
#   ENVIRONMENT_VARS:
#
#   INSTANCE:
#     CLIENT_FORCE_RETURN_ALIGNED_ARRAYS: False
#     CLIENT_INTERNAL_TIMEOUT_SECONDS: 2.0
#     CLIENT_VERBOSE_ALLOCATIONS: False
#     CLIENT_VERBOSE_EXCEPTIONS: True
#     CLIENT_VERBOSE_RPC_CALLS: False
#     COMMAND_LINE_ARGS:
#       fullstdoutlogoutput: None
#       graphicsadapter: 0
#       nologtimes: None
#       nosound: None
#       resx: 512
#       resy: 512
#       stdout: None
#       windowed: None
#     EDITOR_EXECUTABLE:
#     EDITOR_LAUNCH_MODE:
#     EDITOR_UPROJECT:
#     GAME_EXECUTABLE: /Users/miroberts/code/github/spear/cpp/unreal_projects/SpearSim/Standalone-Development/Mac/SpearSim.app
#     GET_EDITOR_WAIT_MAX_TIME_SECONDS: 5.0
#     GET_EDITOR_WAIT_SLEEP_TIME_SECONDS: 1.0
#     GET_EDITOR_WARM_UP_NUM_FRAMES: 1
#     GET_EDITOR_WARM_UP_TIME_SECONDS: 5.0
#     GET_GAME_WAIT_MAX_TIME_SECONDS: 5.0
#     GET_GAME_WAIT_SLEEP_TIME_SECONDS: 1.0
#     GET_GAME_WARM_UP_NUM_FRAMES: 1
#     GET_GAME_WARM_UP_TIME_SECONDS: 5.0
#     INITIALIZE_CLIENT_MAX_TIME_SECONDS: 120.0
#     INITIALIZE_CLIENT_SLEEP_TIME_SECONDS: 1.0
#     INSTANCE_WARM_UP_NUM_FRAMES: 1
#     INSTANCE_WARM_UP_TIME_SECONDS: 5.0
#     PRINT_CALL_DEBUG_INFO: False
#     REQUEST_EXIT_UNREAL_INSTANCE_SLEEP_TIME_SECONDS: 1.0
#     TEMP_CONFIG_FILE: config.yaml
#     TEMP_DIR: tmp
#   LAUNCH_MODE: game
# SP_CORE:
#   PRINT_FIND_ACTOR_AND_GET_COMPONENT_DEBUG_INFO: False
#   SHARED_MEMORY_INITIAL_UNIQUE_ID: 0
#   WAIT_FOR_KEYBOARD_INPUT_DURING_INITIALIZATION: False
# SP_SERVICES:
#   ENGINE_SERVICE:
#     PRINT_CALL_DEBUG_INFO: False
#     PRINT_FRAME_DEBUG_INFO: False
#   ENHANCED_INPUT_SERVICE:
#     PRINT_INJECT_DEBUG_INFO: False
#   INITIALIZE_ENGINE_SERVICE:
#     BENCHMARKING: True
#     EDITOR_STARTUP_MAP:
#     FIXED_DELTA_TIME: 0.033333
#     GAME_DEFAULT_MAP:
#     GLOBAL_DEFAULT_GAME_MODE:
#     MOUNT_PAK_FILES: False
#     NAVIGATION_SYSTEM_DEFAULT_OBJECT_STRING: '{}'
#     OVERRIDE_BENCHMARKING: True
#     OVERRIDE_EDITOR_STARTUP_MAP: False
#     OVERRIDE_FIXED_DELTA_TIME: True
#     OVERRIDE_GAME_DEFAULT_MAP: False
#     OVERRIDE_GLOBAL_DEFAULT_GAME_MODE: False
#     OVERRIDE_NAVIGATION_SYSTEM_DEFAULT_OBJECT: False
#     OVERRIDE_PHYSICS_SETTINGS: False
#     OVERRIDE_RECAST_NAV_MESH_DEFAULT_OBJECT: False
#     PAK_FILES: []
#     PHYSICS_SETTINGS_STRING: '{}'
#     RECAST_NAV_MESH_DEFAULT_OBJECT_STRING: '{}'
#   INITIALIZE_GAME_WORLD_SERVICE:
#     CONSOLE_COMMANDS: []
#     EXECUTE_CONSOLE_COMMANDS: False
#     FORCE_SKYLIGHT_UPDATE: True
#     FORCE_SKYLIGHT_UPDATE_MAX_DURATION_SECONDS: 1.0
#     GAME_PAUSED: True
#     OVERRIDE_GAME_PAUSED: True
#   INPUT_SERVICE:
#     PRINT_INJECT_DEBUG_INFO: False
#   RPC_SERVICE:
#     RPC_SERVER_PORT: 30000
#   WORK_QUEUE:
#     PRINT_CALL_DEBUG_INFO: False
# [SPEAR | instance.py:0404]         Finished requesting to launch Unreal instance.
# [SPEAR | instance.py:0409]     _initialize_client
# [SPEAR | instance.py:0410]         Initializing client...
# [SPEAR | instance.py:0447]         Attempting to connect to server...
# [SPEAR | spear_ext.cpp] Client::Client(...)
# [SPEAR | spear_ext.cpp] Client::terminate()
# [SPEAR | spear_ext.cpp] Client::~Client()
# 2025-12-31 00:05:40.184 SpearSim[92661:28105845] [UE4] Shutdown handler: initialize.
# LogCore: Display: UTS: The Unreal Trace Server binary is not available ('../../../Engine/Binaries/Mac/UnrealTraceServer')
# LogTrace: Initializing trace...
# LogTrace: Finished trace initialization.
# LogCsvProfiler: Display: Metadata set : platform="Mac"
# LogCsvProfiler: Display: Metadata set : config="Development"
# LogCsvProfiler: Display: Metadata set : buildversion="++UE5+Release-5.5-CL-37670630"
# LogCsvProfiler: Display: Metadata set : engineversion="5.5.0-37670630+++UE5+Release-5.5"
# LogCsvProfiler: Display: Metadata set : os="macOS 15.0.1 24A348"
# LogCsvProfiler: Display: Metadata set : cpu="Apple|Apple M3 Max"
# LogCsvProfiler: Display: Metadata set : pgoenabled="0"
# LogCsvProfiler: Display: Metadata set : pgoprofilingenabled="0"
# LogCsvProfiler: Display: Metadata set : ltoenabled="0"
# LogCsvProfiler: Display: Metadata set : asan="0"
# LogCsvProfiler: Display: Metadata set : commandline="" -resx=512 -resy=512 -graphicsadapter=0 -windowed -nosound -stdout -fullstdoutlogoutput -nologtimes -config_file=/Users/miroberts/code/github/spear/examples/getting_started_notebook/tmp/config.yaml -installed""
# LogCsvProfiler: Display: Metadata set : loginid="2bdac52e604fd9336ab20eaeddd2fe78"
# LogCsvProfiler: Display: Metadata set : llm="0"
# LogStats: Stats thread started at 0.458844
# LogAssetRegistry: Premade AssetRegistry loaded from '../../../SpearSim/AssetRegistry.bin'
# LogIris: FNetObjectFactoryRegistry::UnregisterFactory is unregistering factory: None name: NetActorFactory id: 0
# LogIris: FNetObjectFactoryRegistry::UnregisterFactory is unregistering factory: None name: NetSubObjectFactory id: 1
# LogICUInternationalization: OS requested locale 'en-US' is not supported. Using the OS requested language of 'en-US' as the locale.
# LogICUInternationalization: ICU TimeZone Detection - Raw Offset: -5:00, Platform Override: ''
# LogInit: Session CrashGUID >====================================================
#          Session CrashGUID >   UECC-Mac-1C3BE1535D48EFB93F409388897C6C83
#          Session CrashGUID >====================================================
# LogConfig: No local boot hotfix file found at: [/Users/miroberts/Library/Application Support/Epic/SpearSim/Saved/PersistentDownloadDir/HotfixForNextBoot.txt]
# LogPluginManager: Mounting Engine plugin EnhancedInput
# LogPluginManager: Mounting Engine plugin ChaosCloth
# LogPluginManager: Mounting Engine plugin MeshPainting
# LogPluginManager: Mounting Engine plugin TraceUtilities
# LogPluginManager: Mounting Engine plugin Bridge
# LogPluginManager: Mounting Engine plugin Fab
# LogPluginManager: Mounting Engine plugin ChaosClothAsset
# LogPluginManager: Mounting Engine plugin ChaosVD
# LogPluginManager: Mounting Engine plugin WorldMetrics
# LogPluginManager: Mounting Engine plugin Takes
# LogPluginManager: Mounting Engine plugin NNERuntimeORT
# LogPluginManager: Mounting Engine plugin ControlRigSpline
# LogPluginManager: Mounting Engine plugin NNEDenoiser
# LogPluginManager: Mounting Engine plugin RigLogic
# LogPluginManager: Mounting Engine plugin LiveLink
# LogPluginManager: Mounting Engine plugin IKRig
# LogPluginManager: Mounting Engine plugin ACLPlugin
# LogPluginManager: Mounting Engine plugin ControlRig
# LogPluginManager: Mounting Engine plugin ControlRigModules
# LogPluginManager: Mounting Engine plugin AnimationData
# LogPluginManager: Mounting Engine plugin OodleNetwork
# LogPluginManager: Mounting Engine plugin MediaPlate
# LogPluginManager: Mounting Engine plugin MediaCompositing
# LogPluginManager: Mounting Engine plugin DeformerGraph
# LogPluginManager: Mounting Engine plugin ImgMedia
# LogPluginManager: Mounting Engine plugin WmfMedia
# LogPluginManager: Mounting Engine plugin AvfMedia
# LogPluginManager: Mounting Engine plugin WebMMedia
# LogPluginManager: Mounting Engine plugin Dataflow
# LogPluginManager: Mounting Engine plugin ChaosVehiclesPlugin
# LogPluginManager: Mounting Engine plugin LocalizableMessage
# LogPluginManager: Mounting Engine plugin BackChannel
# LogPluginManager: Mounting Engine plugin AutomationUtils
# LogPluginManager: Mounting Engine plugin PythonScriptPlugin
# LogPluginManager: Mounting Engine plugin ChaosNiagara
# LogPluginManager: Mounting Engine plugin ChaosUserDataPT
# LogPluginManager: Mounting Engine plugin ToolPresets
# LogPluginManager: Mounting Engine plugin StudioTelemetry
# LogPluginManager: Mounting Engine plugin ChaosSolverPlugin
# LogPluginManager: Mounting Engine plugin ChaosEditor
# LogPluginManager: Mounting Engine plugin MeshModelingToolsetExp
# LogPluginManager: Mounting Engine plugin PlatformCrypto
# LogPluginManager: Mounting Engine plugin FullBodyIK
# LogPluginManager: Mounting Engine plugin EditorDataStorage
# LogPluginManager: Mounting Engine plugin ChaosCaching
# LogPluginManager: Mounting Engine plugin CharacterAI
# LogPluginManager: Mounting Engine plugin PlanarCut
# LogPluginManager: Mounting Engine plugin GeometryCollectionPlugin
# LogPluginManager: Mounting Engine plugin Fracture
# LogPluginManager: Mounting Engine plugin MoviePipelineMaskRenderPass
# LogPluginManager: Mounting Engine plugin TemplateSequence
# LogPluginManager: Mounting Engine plugin ActorSequence
# LogPluginManager: Mounting Engine plugin MovieRenderPipeline
# LogPluginManager: Mounting Engine plugin LevelSequenceEditor
# LogPluginManager: Mounting Engine plugin SequencerScripting
# LogPluginManager: Mounting Engine plugin OnlineSubsystem
# LogPluginManager: Mounting Engine plugin OpenColorIO
# LogPluginManager: Mounting Engine plugin OnlineSubsystemUtils
# LogPluginManager: Mounting Engine plugin EOSShared
# LogPluginManager: Mounting Engine plugin OnlineServices
# LogPluginManager: Mounting Engine plugin OnlineSubsystemNull
# LogPluginManager: Mounting Engine plugin OnlineBase
# LogPluginManager: Mounting Engine plugin PluginUtils
# LogPluginManager: Mounting Engine plugin DumpGPUServices
# LogPluginManager: Mounting Engine plugin AnimationSharing
# LogPluginManager: Mounting Engine plugin NiagaraSimCaching
# LogPluginManager: Mounting Engine plugin Niagara
# LogPluginManager: Mounting Engine plugin UObjectPlugin
# LogPluginManager: Mounting Engine plugin InterchangeTests
# LogPluginManager: Mounting Engine plugin AISupport
# LogPluginManager: Mounting Engine plugin EnvironmentQueryEditor
# LogPluginManager: Mounting Engine plugin Paper2D
# LogPluginManager: Mounting Engine plugin LauncherChunkInstaller
# LogPluginManager: Mounting Engine plugin GLTFExporter
# LogPluginManager: Mounting Engine plugin VariantManager
# LogPluginManager: Mounting Engine plugin DatasmithContent
# LogPluginManager: Mounting Engine plugin VariantManagerContent
# LogPluginManager: Mounting Engine plugin CableComponent
# LogPluginManager: Mounting Engine plugin USDCore
# LogPluginManager: Mounting Engine plugin SoundFields
# LogPluginManager: Mounting Engine plugin InputDebugging
# LogPluginManager: Mounting Engine plugin ProceduralMeshComponent
# LogPluginManager: Mounting Engine plugin ResonanceAudio
# LogPluginManager: Mounting Engine plugin WebMMoviePlayer
# LogPluginManager: Mounting Engine plugin AndroidFileServer
# LogPluginManager: Mounting Engine plugin AudioWidgets
# LogPluginManager: Mounting Engine plugin RigVM
# LogPluginManager: Mounting Engine plugin AssetTags
# LogPluginManager: Mounting Engine plugin ActorLayerUtilities
# LogPluginManager: Mounting Engine plugin CustomMeshComponent
# LogPluginManager: Mounting Engine plugin AndroidPermission
# LogPluginManager: Mounting Engine plugin Synthesis
# LogPluginManager: Mounting Engine plugin PropertyAccessEditor
# LogPluginManager: Mounting Engine plugin GooglePAD
# LogPluginManager: Mounting Engine plugin MobilePatchingUtils
# LogPluginManager: Mounting Engine plugin HairStrands
# LogPluginManager: Mounting Engine plugin MeshModelingToolset
# LogPluginManager: Mounting Engine plugin ComputeFramework
# LogPluginManager: Mounting Engine plugin MsQuic
# LogPluginManager: Mounting Engine plugin AudioCapture
# LogPluginManager: Mounting Engine plugin SignificanceManager
# LogPluginManager: Mounting Engine plugin ChunkDownloader
# LogPluginManager: Mounting Engine plugin WaveTable
# LogPluginManager: Mounting Engine plugin AppleImageUtils
# LogPluginManager: Mounting Engine plugin ExampleDeviceProfileSelector
# LogPluginManager: Mounting Engine plugin AudioSynesthesia
# LogPluginManager: Mounting Engine plugin StateTree
# LogPluginManager: Mounting Engine plugin HDRIBackdrop
# LogPluginManager: Mounting Engine plugin AppleMoviePlayer
# LogPluginManager: Mounting Engine plugin GeometryCache
# LogPluginManager: Mounting Engine plugin LocationServicesBPLibrary
# LogPluginManager: Mounting Engine plugin GeometryProcessing
# LogPluginManager: Mounting Engine plugin ArchVisCharacter
# LogPluginManager: Mounting Engine plugin Metasound
# LogPluginManager: Mounting Engine plugin GameplayCameras
# LogPluginManager: Mounting Engine plugin CameraShakePreviewer
# LogPluginManager: Mounting Engine plugin EngineCameras
# LogPluginManager: Mounting Engine plugin FacialAnimation
# LogPluginManager: Mounting Engine plugin AssetManagerEditor
# LogPluginManager: Mounting Engine plugin SequencerAnimTools
# LogPluginManager: Mounting Engine plugin BlueprintHeaderView
# LogPluginManager: Mounting Engine plugin EditorScriptingUtilities
# LogPluginManager: Mounting Engine plugin ConsoleVariables
# LogPluginManager: Mounting Engine plugin UVEditor
# LogPluginManager: Mounting Engine plugin ModelingToolsEditorMode
# LogPluginManager: Mounting Engine plugin ProxyLODPlugin
# LogPluginManager: Mounting Engine plugin GeometryMode
# LogPluginManager: Mounting Engine plugin UMGWidgetPreview
# LogPluginManager: Mounting Engine plugin DataValidation
# LogPluginManager: Mounting Engine plugin ColorGrading
# LogPluginManager: Mounting Engine plugin SpeedTreeImporter
# LogPluginManager: Mounting Engine plugin AlembicImporter
# LogPluginManager: Mounting Engine plugin Interchange
# LogPluginManager: Mounting Engine plugin InterchangeEditor
# LogPluginManager: Mounting Engine plugin TcpMessaging
# LogPluginManager: Mounting Engine plugin UdpMessaging
# LogPluginManager: Mounting Engine plugin InterchangeAssets
# LogPluginManager: Mounting Engine plugin SkeletalMeshModelingTools
# LogPluginManager: Mounting Engine plugin ConcertMain
# LogPluginManager: Mounting Engine plugin HoldoutComposite
# LogPluginManager: Mounting Engine plugin SQLiteCore
# LogPluginManager: Mounting Engine plugin ObjectMixer
# LogPluginManager: Mounting Engine plugin LightMixer
# LogPluginManager: Mounting Engine plugin ContentBrowserAssetDataSource
# LogPluginManager: Mounting Engine plugin MetaHumanSDK
# LogPluginManager: Mounting Engine plugin ConcertSharedSlate
# LogPluginManager: Mounting Engine plugin ConcertSyncCore
# LogPluginManager: Mounting Engine plugin ConcertSyncClient
# LogPluginManager: Mounting External plugin SpModuleRules
# LogPluginManager: Mounting External plugin SpCore
# LogPluginManager: Mounting External plugin SpServices
# LogPluginManager: Mounting External plugin SpContent
# LogPluginManager: Mounting External plugin SpUnrealTypes
# [SPEAR | SpCore.cpp:0026] SpCore::StartupModule()
# [SPEAR | Config.cpp:0043] Config::requestInitialize()
# [SPEAR | Config.cpp:0044]     Found config file via the -config_file command-line argument...
# [SPEAR | Config.cpp:0031] Config::initialize(...)
# [SPEAR | Config.cpp:0032]     Initializing config system from file: /Users/miroberts/code/github/spear/examples/getting_started_notebook/tmp/config.yaml
# [SPEAR | SpCore.cpp:0056] SpCore::StartupModule()
# LogInit: Creating http thread with maximum 2147483647 concurrent requests
# LogOnline: OSS: Created online subsystem instance for: NULL
# LogOnline: OSS: TryLoadSubsystemAndSetDefault: Loaded subsystem for type [NULL]
# LogEOSSDK: Initializing EOSSDK Version:1.16.4-36651368
# LogInit: ExecutableName: SpearSim
# LogInit: Build: ++UE5+Release-5.5-CL-37670630
# LogInit: Platform=Mac
# LogInit: MachineId=2bdac52e604fd9336ab20eaeddd2fe78
# LogInit: DeviceId=
# LogInit: Engine Version: 5.5.0-37670630+++UE5+Release-5.5
# LogInit: Compatible Engine Version: 5.5.0-37670630+++UE5+Release-5.5
# LogInit: Net CL: 37670630
# LogInit: OS: macOS 15.0.1 (24A348), CPU: Apple M3 Max, GPU: Apple M3 Max
# LogInit: Compiled (64-bit): Oct 31 2024 18:14:31
# LogInit: Architecture: arm64
# LogInit: Compiled with Clang: 15.0.0 (clang-1500.3.9.4)
# LogInit: Build Configuration: Development
# LogInit: Branch Name: ++UE5+Release-5.5
# LogInit: Command Line:  -resx=512 -resy=512 -graphicsadapter=0 -windowed -nosound -stdout -fullstdoutlogoutput -nologtimes -config_file=/Users/miroberts/code/github/spear/examples/getting_started_notebook/tmp/config.yaml -installed
# LogInit: Base Directory: /Users/miroberts/code/github/spear/cpp/unreal_projects/SpearSim/Standalone-Development/Mac/SpearSim.app/Contents/UE/SpearSim/Binaries/Mac/
# LogInit: Allocator: Binned2
# LogInit: Installed Engine Build: 1
# LogInit: This binary is optimized with LTO: no, PGO: no, instrumented for PGO data collection: no
# LogDevObjectVersion: Number of dev versions registered: 40
# LogDevObjectVersion:   Dev-Blueprints (B0D832E4-1F89-4F0D-ACCF-7EB736FD4AA2): 10
# LogDevObjectVersion:   Dev-Build (E1C64328-A22C-4D53-A36C-8E866417BD8C): 0
# LogDevObjectVersion:   Dev-Core (375EC13C-06E4-48FB-B500-84F0262A717E): 4
# LogDevObjectVersion:   Dev-Editor (E4B068ED-F494-42E9-A231-DA0B2E46BB41): 40
# LogDevObjectVersion:   Dev-Framework (CFFC743F-43B0-4480-9391-14DF171D2073): 37
# LogDevObjectVersion:   Dev-Mobile (B02B49B5-BB20-44E9-A304-32B752E40360): 3
# LogDevObjectVersion:   Dev-Networking (A4E4105C-59A1-49B5-A7C5-40C4547EDFEE): 0
# LogDevObjectVersion:   Dev-Online (39C831C9-5AE6-47DC-9A44-9C173E1C8E7C): 0
# LogDevObjectVersion:   Dev-Physics (78F01B33-EBEA-4F98-B9B4-84EACCB95AA2): 20
# LogDevObjectVersion:   Dev-Platform (6631380F-2D4D-43E0-8009-CF276956A95A): 0
# LogDevObjectVersion:   Dev-Rendering (12F88B9F-8875-4AFC-A67C-D90C383ABD29): 49
# LogDevObjectVersion:   Dev-Sequencer (7B5AE74C-D270-4C10-A958-57980B212A5A): 13
# LogDevObjectVersion:   Dev-VR (D7296918-1DD6-4BDD-9DE2-64A83CC13884): 3
# LogDevObjectVersion:   Dev-LoadTimes (C2A15278-BFE7-4AFE-6C17-90FF531DF755): 1
# LogDevObjectVersion:   Private-Geometry (6EACA3D4-40EC-4CC1-B786-8BED09428FC5): 3
# LogDevObjectVersion:   Dev-AnimPhys (29E575DD-E0A3-4627-9D10-D276232CDCEA): 17
# LogDevObjectVersion:   Dev-Anim (AF43A65D-7FD3-4947-9873-3E8ED9C1BB05): 15
# LogDevObjectVersion:   Dev-ReflectionCapture (6B266CEC-1EC7-4B8F-A30B-E4D90942FC07): 1
# LogDevObjectVersion:   Dev-Automation (0DF73D61-A23F-47EA-B727-89E90C41499A): 1
# LogDevObjectVersion:   FortniteMain (601D1886-AC64-4F84-AA16-D3DE0DEAC7D6): 170
# LogDevObjectVersion:   FortniteValkyrie (8DBC2C5B-54A7-43E0-A768-FCBB7DA29060): 8
# LogDevObjectVersion:   FortniteSeason (5B4C06B7-2463-4AF8-805B-BF70CDF5D0DD): 13
# LogDevObjectVersion:   FortniteRelease (E7086368-6B23-4C58-8439-1B7016265E91): 15
# LogDevObjectVersion:   Dev-Enterprise (9DFFBCD6-494F-0158-E221-12823C92A888): 10
# LogDevObjectVersion:   Dev-Niagara (F2AED0AC-9AFE-416F-8664-AA7FFA26D6FC): 1
# LogDevObjectVersion:   Dev-Destruction (174F1F0B-B4C6-45A5-B13F-2EE8D0FB917D): 10
# LogDevObjectVersion:   Dev-Physics-Ext (35F94A83-E258-406C-A318-09F59610247C): 41
# LogDevObjectVersion:   Dev-PhysicsMaterial-Chaos (B68FC16E-8B1B-42E2-B453-215C058844FE): 1
# LogDevObjectVersion:   Dev-CineCamera (B2E18506-4273-CFC2-A54E-F4BB758BBA07): 1
# LogDevObjectVersion:   Dev-VirtualProduction (64F58936-FD1B-42BA-BA96-7289D5D0FA4E): 1
# LogDevObjectVersion:   UE5-Main (697DD581-E64F-41AB-AA4A-51ECBEB7B628): 119
# LogDevObjectVersion:   UE5-Release (D89B5E42-24BD-4D46-8412-ACA8DF641779): 51
# LogDevObjectVersion:   UE5-PrivateFrosty (59DA5D52-1232-4948-B878-597870B8E98B): 8
# LogDevObjectVersion:   Dev-MediaFramework (6F0ED827-A609-4895-9C91-998D90180EA4): 2
# LogDevObjectVersion:   Dev-NaniteResearch (30D58BE3-95EA-4282-A6E3-B159D8EBB06A): 1
# LogDevObjectVersion:   Dev-RigVM (DC49959B-53C0-4DE7-9156-EA885E7C5D39): 15
# LogDevObjectVersion:   Dev-ControlRig (A7820CFB-20A7-4359-8C54-2C149623CF50): 32
# LogDevObjectVersion:   Dev-IKRig (F6DFBB78-BB50-A0E4-4018-B84D60CBAF23): 2
# LogDevObjectVersion:   Dev-ComputeFramework (6304A3E7-0059-4F59-8CFC-21BD7721FD4E): 0
# LogDevObjectVersion:   Dev-Optimus (93EDE1AA-10CA-7375-4DF9-8A2849B157A0): 12
# LogConfig: Branch 'Lightmass' had been unloaded. Reloading on-demand took 0.07ms
# LogConfig: Branch 'ChaosCloth' had been unloaded. Reloading on-demand took 0.02ms
# LogConfig: Branch 'MeshPainting' had been unloaded. Reloading on-demand took 0.01ms
# LogConfig: Branch 'Bridge' had been unloaded. Reloading on-demand took 0.01ms
# LogConfig: Branch 'ChaosClothAsset' had been unloaded. Reloading on-demand took 0.01ms
# LogConfig: Branch 'WorldMetrics' had been unloaded. Reloading on-demand took 0.01ms
# LogConfig: Branch 'NNERuntimeORT' had been unloaded. Reloading on-demand took 0.01ms
# LogConfig: Branch 'ControlRigSpline' had been unloaded. Reloading on-demand took 0.01ms
# LogConfig: Branch 'NNEDenoiser' had been unloaded. Reloading on-demand took 0.01ms
# LogConfig: Branch 'RigLogic' had been unloaded. Reloading on-demand took 0.01ms
# LogConfig: Branch 'ACLPlugin' had been unloaded. Reloading on-demand took 0.01ms
# LogConfig: Branch 'ControlRigModules' had been unloaded. Reloading on-demand took 0.01ms
# LogConfig: Branch 'AnimationData' had been unloaded. Reloading on-demand took 0.01ms
# LogConfig: Branch 'OodleNetwork' had been unloaded. Reloading on-demand took 0.01ms
# LogConfig: Branch 'MediaPlate' had been unloaded. Reloading on-demand took 0.01ms
# LogConfig: Branch 'MediaCompositing' had been unloaded. Reloading on-demand took 0.01ms
# LogConfig: Branch 'ImgMedia' had been unloaded. Reloading on-demand took 0.01ms
# LogConfig: Branch 'WmfMedia' had been unloaded. Reloading on-demand took 0.01ms
# LogConfig: Branch 'AvfMedia' had been unloaded. Reloading on-demand took 0.01ms
# LogConfig: Branch 'WebMMedia' had been unloaded. Reloading on-demand took 0.01ms
# LogConfig: Branch 'Dataflow' had been unloaded. Reloading on-demand took 0.01ms
# LogConfig: Branch 'ChaosVehiclesPlugin' had been unloaded. Reloading on-demand took 0.01ms
# LogConfig: Branch 'LocalizableMessage' had been unloaded. Reloading on-demand took 0.01ms
# LogConfig: Branch 'BackChannel' had been unloaded. Reloading on-demand took 0.01ms
# LogConfig: Branch 'AutomationUtils' had been unloaded. Reloading on-demand took 0.01ms
# LogConfig: Branch 'PythonScriptPlugin' had been unloaded. Reloading on-demand took 0.01ms
# LogConfig: Branch 'ChaosNiagara' had been unloaded. Reloading on-demand took 0.01ms
# LogConfig: Branch 'ChaosUserDataPT' had been unloaded. Reloading on-demand took 0.01ms
# LogConfig: Branch 'StudioTelemetry' had been unloaded. Reloading on-demand took 0.01ms
# LogConfig: Branch 'ChaosSolverPlugin' had been unloaded. Reloading on-demand took 0.01ms
# LogConfig: Branch 'ChaosEditor' had been unloaded. Reloading on-demand took 0.01ms
# LogConfig: Branch 'MeshModelingToolsetExp' had been unloaded. Reloading on-demand took 0.01ms
# LogConfig: Branch 'PlatformCrypto' had been unloaded. Reloading on-demand took 0.01ms
# LogConfig: Branch 'EditorDataStorage' had been unloaded. Reloading on-demand took 0.01ms
# LogConfig: Branch 'ChaosCaching' had been unloaded. Reloading on-demand took 0.01ms
# LogConfig: Branch 'CharacterAI' had been unloaded. Reloading on-demand took 0.01ms
# LogConfig: Branch 'PlanarCut' had been unloaded. Reloading on-demand took 0.01ms
# LogConfig: Branch 'GeometryCollectionPlugin' had been unloaded. Reloading on-demand took 0.02ms
# LogConfig: Branch 'Fracture' had been unloaded. Reloading on-demand took 0.01ms
# LogConfig: Branch 'MoviePipelineMaskRenderPass' had been unloaded. Reloading on-demand took 0.01ms
# LogConfig: Branch 'TemplateSequence' had been unloaded. Reloading on-demand took 0.01ms
# LogConfig: Branch 'ActorSequence' had been unloaded. Reloading on-demand took 0.01ms
# LogConfig: Branch 'LevelSequenceEditor' had been unloaded. Reloading on-demand took 0.01ms
# LogConfig: Branch 'SequencerScripting' had been unloaded. Reloading on-demand took 0.01ms
# LogConfig: Branch 'OnlineSubsystem' had been unloaded. Reloading on-demand took 0.01ms
# LogConfig: Branch 'OnlineSubsystemUtils' had been unloaded. Reloading on-demand took 0.01ms
# LogConfig: Branch 'EOSShared' had been unloaded. Reloading on-demand took 0.01ms
# LogConfig: Branch 'OnlineServices' had been unloaded. Reloading on-demand took 0.01ms
# LogConfig: Branch 'OnlineSubsystemNull' had been unloaded. Reloading on-demand took 0.01ms
# LogConfig: Branch 'OnlineBase' had been unloaded. Reloading on-demand took 0.01ms
# LogConfig: Branch 'PluginUtils' had been unloaded. Reloading on-demand took 0.01ms
# LogConfig: Branch 'DumpGPUServices' had been unloaded. Reloading on-demand took 0.01ms
# LogConfig: Branch 'AnimationSharing' had been unloaded. Reloading on-demand took 0.01ms
# LogConfig: Branch 'NiagaraSimCaching' had been unloaded. Reloading on-demand took 0.01ms
# LogConfig: Branch 'UObjectPlugin' had been unloaded. Reloading on-demand took 0.01ms
# LogConfig: Branch 'InterchangeTests' had been unloaded. Reloading on-demand took 0.01ms
# LogConfig: Branch 'AISupport' had been unloaded. Reloading on-demand took 0.01ms
# LogConfig: Branch 'EnvironmentQueryEditor' had been unloaded. Reloading on-demand took 0.01ms
# LogConfig: Branch 'LauncherChunkInstaller' had been unloaded. Reloading on-demand took 0.01ms
# LogConfig: Branch 'VariantManager' had been unloaded. Reloading on-demand took 0.01ms
# LogConfig: Branch 'CableComponent' had been unloaded. Reloading on-demand took 0.01ms
# LogConfig: Branch 'SoundFields' had been unloaded. Reloading on-demand took 0.01ms
# LogConfig: Branch 'InputDebugging' had been unloaded. Reloading on-demand took 0.01ms
# LogConfig: Branch 'ProceduralMeshComponent' had been unloaded. Reloading on-demand took 0.01ms
# LogConfig: Branch 'ResonanceAudio' had been unloaded. Reloading on-demand took 0.01ms
# LogConfig: Branch 'WebMMoviePlayer' had been unloaded. Reloading on-demand took 0.01ms
# LogConfig: Branch 'AndroidFileServer' had been unloaded. Reloading on-demand took 0.01ms
# LogConfig: Branch 'AudioWidgets' had been unloaded. Reloading on-demand took 0.01ms
# LogConfig: Branch 'AssetTags' had been unloaded. Reloading on-demand took 0.01ms
# LogConfig: Branch 'ActorLayerUtilities' had been unloaded. Reloading on-demand took 0.01ms
# LogConfig: Branch 'CustomMeshComponent' had been unloaded. Reloading on-demand took 0.01ms
# LogConfig: Branch 'AndroidPermission' had been unloaded. Reloading on-demand took 0.01ms
# LogConfig: Branch 'PropertyAccessEditor' had been unloaded. Reloading on-demand took 0.01ms
# LogConfig: Branch 'GooglePAD' had been unloaded. Reloading on-demand took 0.01ms
# LogConfig: Branch 'MobilePatchingUtils' had been unloaded. Reloading on-demand took 0.01ms
# LogConfig: Branch 'MeshModelingToolset' had been unloaded. Reloading on-demand took 0.01ms
# LogConfig: Branch 'ComputeFramework' had been unloaded. Reloading on-demand took 0.01ms
# LogConfig: Branch 'MsQuic' had been unloaded. Reloading on-demand took 0.01ms
# LogConfig: Branch 'AudioCapture' had been unloaded. Reloading on-demand took 0.01ms
# LogConfig: Branch 'SignificanceManager' had been unloaded. Reloading on-demand took 0.01ms
# LogConfig: Branch 'ChunkDownloader' had been unloaded. Reloading on-demand took 0.01ms
# LogConfig: Branch 'WaveTable' had been unloaded. Reloading on-demand took 0.01ms
# LogConfig: Branch 'AppleImageUtils' had been unloaded. Reloading on-demand took 0.01ms
# LogConfig: Branch 'ExampleDeviceProfileSelector' had been unloaded. Reloading on-demand took 0.01ms
# LogConfig: Branch 'AudioSynesthesia' had been unloaded. Reloading on-demand took 0.01ms
# LogConfig: Branch 'HDRIBackdrop' had been unloaded. Reloading on-demand took 0.01ms
# LogConfig: Branch 'AppleMoviePlayer' had been unloaded. Reloading on-demand took 0.01ms
# LogConfig: Branch 'GeometryCache' had been unloaded. Reloading on-demand took 0.01ms
# LogConfig: Branch 'LocationServicesBPLibrary' had been unloaded. Reloading on-demand took 0.01ms
# LogConfig: Branch 'GeometryProcessing' had been unloaded. Reloading on-demand took 0.01ms
# LogConfig: Branch 'ArchVisCharacter' had been unloaded. Reloading on-demand took 0.01ms
# LogConfig: Branch 'CameraShakePreviewer' had been unloaded. Reloading on-demand took 0.01ms
# LogConfig: Branch 'EngineCameras' had been unloaded. Reloading on-demand took 0.01ms
# LogConfig: Branch 'FacialAnimation' had been unloaded. Reloading on-demand took 0.01ms
# LogConfig: Branch 'AssetManagerEditor' had been unloaded. Reloading on-demand took 0.01ms
# LogConfig: Branch 'SequencerAnimTools' had been unloaded. Reloading on-demand took 0.01ms
# LogConfig: Branch 'BlueprintHeaderView' had been unloaded. Reloading on-demand took 0.02ms
# LogConfig: Branch 'UVEditor' had been unloaded. Reloading on-demand took 0.01ms
# LogConfig: Branch 'ModelingToolsEditorMode' had been unloaded. Reloading on-demand took 0.01ms
# LogConfig: Branch 'ProxyLODPlugin' had been unloaded. Reloading on-demand took 0.01ms
# LogConfig: Branch 'GeometryMode' had been unloaded. Reloading on-demand took 0.01ms
# LogConfig: Branch 'UMGWidgetPreview' had been unloaded. Reloading on-demand took 0.01ms
# LogConfig: Branch 'DataValidation' had been unloaded. Reloading on-demand took 0.01ms
# LogConfig: Branch 'ColorGrading' had been unloaded. Reloading on-demand took 0.01ms
# LogConfig: Branch 'SpeedTreeImporter' had been unloaded. Reloading on-demand took 0.01ms
# LogConfig: Branch 'AlembicImporter' had been unloaded. Reloading on-demand took 0.01ms
# LogConfig: Branch 'InterchangeEditor' had been unloaded. Reloading on-demand took 0.01ms
# LogConfig: Branch 'TcpMessaging' had been unloaded. Reloading on-demand took 0.01ms
# LogConfig: Branch 'UdpMessaging' had been unloaded. Reloading on-demand took 0.01ms
# LogConfig: Branch 'SkeletalMeshModelingTools' had been unloaded. Reloading on-demand took 0.01ms
# LogConfig: Branch 'ConcertMain' had been unloaded. Reloading on-demand took 0.01ms
# LogConfig: Branch 'SQLiteCore' had been unloaded. Reloading on-demand took 0.01ms
# LogConfig: Branch 'ObjectMixer' had been unloaded. Reloading on-demand took 0.01ms
# LogConfig: Branch 'LightMixer' had been unloaded. Reloading on-demand took 0.01ms
# LogConfig: Branch 'ContentBrowserAssetDataSource' had been unloaded. Reloading on-demand took 0.01ms
# LogConfig: Branch 'ConcertSharedSlate' had been unloaded. Reloading on-demand took 0.01ms
# LogConfig: Branch 'ConcertSyncClient' had been unloaded. Reloading on-demand took 0.01ms
# LogConfig: Branch 'SpModuleRules' had been unloaded. Reloading on-demand took 0.03ms
# LogConfig: Branch 'SpCore' had been unloaded. Reloading on-demand took 0.02ms
# LogConfig: Branch 'SpServices' had been unloaded. Reloading on-demand took 0.02ms
# LogConfig: Branch 'SpContent' had been unloaded. Reloading on-demand took 0.02ms
# LogConfig: Branch 'SpUnrealTypes' had been unloaded. Reloading on-demand took 0.01ms
# LogInit: Presizing for max 2097152 objects, including 1 objects not considered by GC.
# LogStreaming: Display: AsyncLoading2 - Created: Event Driven Loader: false, Async Loading Thread: true, Async Post Load: true
# LogStreaming: Display: AsyncLoading2 - Initialized
# LogInit: Object subsystem initialized
# LogConfig: Set CVar [[con.DebugEarlyDefault:1]]
# LogConfig: CVar [[con.DebugLateDefault:1]] deferred - dummy variable created
# LogConfig: CVar [[con.DebugLateCheat:1]] deferred - dummy variable created
# LogConfig: CVar [[LogNamedEventFilters:Frame *]] deferred - dummy variable created
# LogConfig: Set CVar [[r.setres:1280x720]]
# LogConfig: Set CVar [[g.TimeoutForBlockOnRenderFence:300000]]
# LogConfig: CVar [[framepro.ScopeMinTimeMicroseconds:10]] deferred - dummy variable created
# LogConfig: Set CVar [[fx.NiagaraAllowRuntimeScalabilityChanges:1]]
# LogConfig: CVar [[QualityLevelMapping:high]] deferred - dummy variable created
# LogConfig: Set CVar [[r.OneFrameThreadLag:0]]
# LogConfig: Set CVar [[r.GTSyncType:1]]
# LogConfig: CVar [[con.DebugLateDefault:1]] deferred - dummy variable created
# LogConfig: CVar [[con.DebugLateCheat:1]] deferred - dummy variable created
# LogConfig: CVar [[LogNamedEventFilters:Frame *]] deferred - dummy variable created
# LogConfig: CVar [[framepro.ScopeMinTimeMicroseconds:10]] deferred - dummy variable created
# LogConfig: CVar [[QualityLevelMapping:high]] deferred - dummy variable created
# LogConfig: Applying CVar settings from Section [/Script/Engine.RendererSettings] File [Engine]
# LogConfig: CVar [[VisualizeCalibrationColorMaterialPath:/Engine/EngineMaterials/PPM_DefaultCalibrationColor.PPM_DefaultCalibrationColor]] deferred - dummy variable created
# LogConfig: CVar [[VisualizeCalibrationGrayscaleMaterialPath:/Engine/EngineMaterials/PPM_DefaultCalibrationGrayscale.PPM_DefaultCalibrationGrayscale]] deferred - dummy variable created
# LogConfig: Set CVar [[r.GPUCrashDebugging:0]]
# LogConfig: CVar [[MaxSkinBones:(Default=65536,PerPlatform=(("Mobile", 256)))]] deferred - dummy variable created
# LogConfig: Set CVar [[r.CustomDepth:3 ; r.CustomDepth=3 enables a custom depth-stencil pass with stencil enabled]]
# LogConfig: Set CVar [[r.EyeAdaptation.ExponentialTransitionDistance:0.5]]
# LogConfig: CVar [[r.Shaders.CompressionFormat:0]] deferred - dummy variable created
# LogConfig: Set CVar [[r.AllowStaticLighting:0]]
# LogConfig: Set CVar [[r.RayTracing:1]]
# LogConfig: Set CVar [[r.SkinCache.CompileShaders:1]]
# LogConfig: CVar [[r.RayTracing.Enable:0]] deferred - dummy variable created
# LogConfig: Set CVar [[r.RayTracing.EnableOnDemand:1]]
# LogConfig: Set CVar [[r.DefaultFeature.AutoExposure.ExtendDefaultLuminanceRange:1]]
# LogConfig: Set CVar [[r.DefaultFeature.LocalExposure.HighlightContrastScale:0.8]]
# LogConfig: Set CVar [[r.DefaultFeature.LocalExposure.ShadowContrastScale:0.8]]
# LogConfig: Set CVar [[r.DynamicGlobalIlluminationMethod:1]]
# LogConfig: Set CVar [[r.GenerateMeshDistanceFields:1]]
# LogConfig: Set CVar [[r.Lumen.TraceMeshSDFs:0]]
# LogConfig: CVar [[r.Mobile.EnableNoPrecomputedLightingCSMShader:1]] deferred - dummy variable created
# LogConfig: Set CVar [[r.ReflectionMethod:1]]
# LogConfig: Set CVar [[r.Shadow.Virtual.Enable:1]]
# LogConfig: Applying CVar settings from Section [/Script/Engine.RendererOverrideSettings] File [Engine]
# LogConfig: Set CVar [[r.SupportAllShaderPermutations:1]]
# LogConfig: Applying CVar settings from Section [/Script/Engine.StreamingSettings] File [Engine]
# LogConfig: Set CVar [[s.MinBulkDataSizeForAsyncLoading:131072]]
# LogConfig: Set CVar [[s.AsyncLoadingThreadEnabled:1]]
# LogConfig: Set CVar [[s.EventDrivenLoaderEnabled:1]]
# LogConfig: Set CVar [[s.WarnIfTimeLimitExceeded:0]]
# LogConfig: Set CVar [[s.TimeLimitExceededMultiplier:1.5]]
# LogConfig: Set CVar [[s.TimeLimitExceededMinTime:0.005]]
# LogConfig: Set CVar [[s.UseBackgroundLevelStreaming:1]]
# LogConfig: Set CVar [[s.PriorityAsyncLoadingExtraTime:15.0]]
# LogConfig: Set CVar [[s.LevelStreamingActorsUpdateTimeLimit:5.0]]
# LogConfig: Set CVar [[s.PriorityLevelStreamingActorsUpdateExtraTime:5.0]]
# LogConfig: Set CVar [[s.LevelStreamingComponentsRegistrationGranularity:10]]
# LogConfig: Set CVar [[s.UnregisterComponentsTimeLimit:1.0]]
# LogConfig: Set CVar [[s.LevelStreamingComponentsUnregistrationGranularity:5]]
# LogConfig: CVar [[s.MaxPackageSummarySize:16384]] deferred - dummy variable created
# LogConfig: Set CVar [[s.FlushStreamingOnExit:1]]
# LogConfig: CVar [[FixedBootOrder:/Script/Engine/Default__SoundBase]] deferred - dummy variable created
# LogConfig: CVar [[FixedBootOrder:/Script/Engine/Default__MaterialInterface]] deferred - dummy variable created
# LogConfig: CVar [[FixedBootOrder:/Script/Engine/Default__DeviceProfileManager]] deferred - dummy variable created
# LogConfig: Applying CVar settings from Section [/Script/Engine.GarbageCollectionSettings] File [Engine]
# LogConfig: Set CVar [[gc.MaxObjectsNotConsideredByGC:1]]
# LogConfig: Set CVar [[gc.FlushStreamingOnGC:0]]
# LogConfig: Set CVar [[gc.NumRetriesBeforeForcingGC:10]]
# LogConfig: Set CVar [[gc.AllowParallelGC:1]]
# LogConfig: Set CVar [[gc.TimeBetweenPurgingPendingKillObjects:61.1]]
# LogConfig: Set CVar [[gc.MaxObjectsInEditor:25165824]]
# LogConfig: Set CVar [[gc.IncrementalBeginDestroyEnabled:1]]
# LogConfig: Set CVar [[gc.CreateGCClusters:1]]
# LogConfig: Set CVar [[gc.MinGCClusterSize:5]]
# LogConfig: Set CVar [[gc.AssetClustreringEnabled:0]]
# LogConfig: Set CVar [[gc.ActorClusteringEnabled:0]]
# LogConfig: Set CVar [[gc.VerifyUObjectsAreNotFGCObjects:0]]
# LogConfig: Set CVar [[gc.GarbageEliminationEnabled:1]]
# LogConfig: Applying CVar settings from Section [/Script/Engine.NetworkSettings] File [Engine]
# LogConfig: CVar [[NetworkEmulationProfiles:(ProfileName="Average",ToolTip="Simulates average internet conditions")]] deferred - dummy variable created
# LogConfig: CVar [[NetworkEmulationProfiles:(ProfileName="Bad",ToolTip="Simulates laggy internet conditions")]] deferred - dummy variable created
# LogConfig: Applying CVar settings from Section [ViewDistanceQuality@3] File [Scalability]
# LogConfig: Set CVar [[r.SkeletalMeshLODBias:0]]
# LogConfig: Set CVar [[r.ViewDistanceScale:1.0]]
# LogConfig: Applying CVar settings from Section [AntiAliasingQuality@3] File [Scalability]
# LogConfig: Set CVar [[r.FXAA.Quality:4]]
# LogConfig: Set CVar [[r.TemporalAA.Quality:2]]
# LogConfig: Set CVar [[r.TSR.History.R11G11B10:1]]
# LogConfig: Set CVar [[r.TSR.History.ScreenPercentage:200]]
# LogConfig: Set CVar [[r.TSR.History.UpdateQuality:3]]
# LogConfig: Set CVar [[r.TSR.ShadingRejection.Flickering:1]]
# LogConfig: Set CVar [[r.TSR.RejectionAntiAliasingQuality:2]]
# LogConfig: Set CVar [[r.TSR.ReprojectionField:1]]
# LogConfig: Set CVar [[r.TSR.Resurrection:1]]
# LogConfig: Applying CVar settings from Section [ShadowQuality@3] File [Scalability]
# LogConfig: Set CVar [[r.LightFunctionQuality:1]]
# LogConfig: Set CVar [[r.ShadowQuality:5]]
# LogConfig: Set CVar [[r.Shadow.CSM.MaxCascades:10]]
# LogConfig: Set CVar [[r.Shadow.MaxResolution:2048]]
# LogConfig: Set CVar [[r.Shadow.MaxCSMResolution:2048]]
# LogConfig: Set CVar [[r.Shadow.RadiusThreshold:0.01]]
# LogConfig: Set CVar [[r.Shadow.DistanceScale:1.0]]
# LogConfig: Set CVar [[r.Shadow.CSM.TransitionScale:1.0]]
# LogConfig: Set CVar [[r.Shadow.PreShadowResolutionFactor:1.0]]
# LogConfig: Set CVar [[r.DistanceFieldShadowing:1]]
# LogConfig: Set CVar [[r.VolumetricFog:1]]
# LogConfig: Set CVar [[r.VolumetricFog.GridPixelSize:8]]
# LogConfig: Set CVar [[r.VolumetricFog.GridSizeZ:128]]
# LogConfig: Set CVar [[r.VolumetricFog.HistoryMissSupersampleCount:4]]
# LogConfig: Set CVar [[r.LightMaxDrawDistanceScale:1]]
# LogConfig: Set CVar [[r.CapsuleShadows:1]]
# LogConfig: Set CVar [[r.Shadow.Virtual.MaxPhysicalPages:4096]]
# LogConfig: Set CVar [[r.Shadow.Virtual.ResolutionLodBiasDirectional:-1.5]]
# LogConfig: Set CVar [[r.Shadow.Virtual.ResolutionLodBiasDirectionalMoving:-1.5]]
# LogConfig: Set CVar [[r.Shadow.Virtual.ResolutionLodBiasLocal:0.0]]
# LogConfig: Set CVar [[r.Shadow.Virtual.ResolutionLodBiasLocalMoving:1.0]]
# LogConfig: Set CVar [[r.Shadow.Virtual.SMRT.RayCountDirectional:8]]
# LogConfig: Set CVar [[r.Shadow.Virtual.SMRT.SamplesPerRayDirectional:4]]
# LogConfig: Set CVar [[r.Shadow.Virtual.SMRT.RayCountLocal:8]]
# LogConfig: Set CVar [[r.Shadow.Virtual.SMRT.SamplesPerRayLocal:4]]
# LogConfig: Applying CVar settings from Section [GlobalIlluminationQuality@3] File [Scalability]
# LogConfig: Set CVar [[r.DistanceFieldAO:1]]
# LogConfig: Set CVar [[r.AOQuality:2]]
# LogConfig: Set CVar [[r.Lumen.DiffuseIndirect.Allow:1]]
# LogConfig: Set CVar [[r.LumenScene.Radiosity.ProbeSpacing:4]]
# LogConfig: Set CVar [[r.LumenScene.Radiosity.HemisphereProbeResolution:4]]
# LogConfig: Set CVar [[r.Lumen.TraceMeshSDFs.Allow:1]]
# LogConfig: Set CVar [[r.Lumen.ScreenProbeGather.RadianceCache.ProbeResolution:32]]
# LogConfig: Set CVar [[r.Lumen.ScreenProbeGather.RadianceCache.NumProbesToTraceBudget:300]]
# LogConfig: Set CVar [[r.Lumen.ScreenProbeGather.DownsampleFactor:16]]
# LogConfig: Set CVar [[r.Lumen.ScreenProbeGather.TracingOctahedronResolution:8]]
# LogConfig: Set CVar [[r.Lumen.ScreenProbeGather.IrradianceFormat:0]]
# LogConfig: Set CVar [[r.Lumen.ScreenProbeGather.StochasticInterpolation:0]]
# LogConfig: Set CVar [[r.Lumen.ScreenProbeGather.FullResolutionJitterWidth:1]]
# LogConfig: Set CVar [[r.Lumen.ScreenProbeGather.TwoSidedFoliageBackfaceDiffuse:1]]
# LogConfig: Set CVar [[r.Lumen.ScreenProbeGather.ScreenTraces.HZBTraversal.FullResDepth:1]]
# LogConfig: Set CVar [[r.Lumen.ScreenProbeGather.ShortRangeAO.HardwareRayTracing:0]]
# LogConfig: Set CVar [[r.Lumen.TranslucencyVolume.GridPixelSize:32]]
# LogConfig: Set CVar [[r.Lumen.TranslucencyVolume.TraceFromVolume:1]]
# LogConfig: Set CVar [[r.Lumen.TranslucencyVolume.TracingOctahedronResolution:3]]
# LogConfig: Set CVar [[r.Lumen.TranslucencyVolume.RadianceCache.ProbeResolution:8]]
# LogConfig: Set CVar [[r.Lumen.TranslucencyVolume.RadianceCache.NumProbesToTraceBudget:200]]
# LogConfig: Set CVar [[r.SkyLight.RealTimeReflectionCapture:1]]
# LogConfig: CVar [[r.RayTracing.Scene.BuildMode:1]] deferred - dummy variable created
# LogConfig: Applying CVar settings from Section [ReflectionQuality@3] File [Scalability]
# LogConfig: Set CVar [[r.SSR.Quality:3]]
# LogConfig: Set CVar [[r.SSR.HalfResSceneColor:0]]
# LogConfig: Set CVar [[r.Lumen.Reflections.Allow:1]]
# LogConfig: Set CVar [[r.Lumen.Reflections.DownsampleFactor:1]]
# LogConfig: Set CVar [[r.Lumen.Reflections.MaxRoughnessToTraceForFoliage:0.4]]
# LogConfig: Set CVar [[r.Lumen.ScreenProbeGather.MaxRoughnessToEvaluateRoughSpecularForFoliage:0.8]]
# LogConfig: Set CVar [[r.Lumen.Reflections.ScreenSpaceReconstruction.TonemapMode:1]]
# LogConfig: Set CVar [[r.Lumen.Reflections.ScreenSpaceReconstruction.MinWeight:0]]
# LogConfig: Set CVar [[r.Lumen.TranslucencyReflections.FrontLayer.Allow:1]]
# LogConfig: Set CVar [[r.Lumen.TranslucencyReflections.FrontLayer.Enable:0]]
# LogConfig: Applying CVar settings from Section [PostProcessQuality@3] File [Scalability]
# LogConfig: Set CVar [[r.MotionBlurQuality:4]]
# LogConfig: Set CVar [[r.MotionBlur.HalfResGather:0]]
# LogConfig: Set CVar [[r.AmbientOcclusionMipLevelFactor:0.4]]
# LogConfig: Set CVar [[r.AmbientOcclusionMaxQuality:100]]
# LogConfig: Set CVar [[r.AmbientOcclusionLevels:-1]]
# LogConfig: Set CVar [[r.AmbientOcclusionRadiusScale:1.0]]
# LogConfig: Set CVar [[r.DepthOfFieldQuality:2]]
# LogConfig: Set CVar [[r.RenderTargetPoolMin:400]]
# LogConfig: Set CVar [[r.LensFlareQuality:2]]
# LogConfig: Set CVar [[r.SceneColorFringeQuality:1]]
# LogConfig: Set CVar [[r.EyeAdaptationQuality:2]]
# LogConfig: Set CVar [[r.BloomQuality:5]]
# LogConfig: Set CVar [[r.Bloom.ScreenPercentage:50.000]]
# LogConfig: Set CVar [[r.FastBlurThreshold:100]]
# LogConfig: Set CVar [[r.Upscale.Quality:3]]
# LogConfig: Set CVar [[r.LightShaftQuality:1]]
# LogConfig: Set CVar [[r.Filter.SizeScale:1]]
# LogConfig: Set CVar [[r.Tonemapper.Quality:5]]
# LogConfig: Set CVar [[r.DOF.Gather.ResolutionDivisor:2         ; lower gathering resolution]]
# LogConfig: Set CVar [[r.DOF.Gather.AccumulatorQuality:1        ; higher gathering accumulator quality]]
# LogConfig: Set CVar [[r.DOF.Gather.PostfilterMethod:1          ; Median3x3 postfilering method]]
# LogConfig: Set CVar [[r.DOF.Gather.EnableBokehSettings:0       ; no bokeh simulation when gathering]]
# LogConfig: Set CVar [[r.DOF.Gather.RingCount:4                 ; medium number of samples when gathering]]
# LogConfig: Set CVar [[r.DOF.Scatter.ForegroundCompositing:1    ; additive foreground scattering]]
# LogConfig: Set CVar [[r.DOF.Scatter.BackgroundCompositing:2    ; additive background scattering]]
# LogConfig: Set CVar [[r.DOF.Scatter.EnableBokehSettings:1      ; bokeh simulation when scattering]]
# LogConfig: Set CVar [[r.DOF.Scatter.MaxSpriteRatio:0.1         ; only a maximum of 10% of scattered bokeh]]
# LogConfig: Set CVar [[r.DOF.Recombine.Quality:1                ; cheap slight out of focus]]
# LogConfig: Set CVar [[r.DOF.Recombine.EnableBokehSettings:0    ; no bokeh simulation on slight out of focus]]
# LogConfig: Set CVar [[r.DOF.TemporalAAQuality:1                ; more stable temporal accumulation]]
# LogConfig: Set CVar [[r.DOF.Kernel.MaxForegroundRadius:0.025]]
# LogConfig: Set CVar [[r.DOF.Kernel.MaxBackgroundRadius:0.025]]
# LogConfig: Applying CVar settings from Section [TextureQuality@3] File [Scalability]
# LogConfig: Set CVar [[r.Streaming.MipBias:0]]
# LogConfig: Set CVar [[r.Streaming.AmortizeCPUToGPUCopy:0]]
# LogConfig: Set CVar [[r.Streaming.MaxNumTexturesToStreamPerFrame:0]]
# LogConfig: Set CVar [[r.Streaming.Boost:1]]
# LogConfig: Set CVar [[r.MaxAnisotropy:8]]
# LogConfig: Set CVar [[r.VT.MaxAnisotropy:8]]
# LogConfig: Set CVar [[r.Streaming.LimitPoolSizeToVRAM:0]]
# LogConfig: Set CVar [[r.Streaming.PoolSize:1000]]
# LogConfig: Set CVar [[r.Streaming.MaxEffectiveScreenSize:0]]
# LogConfig: Applying CVar settings from Section [EffectsQuality@3] File [Scalability]
# LogConfig: Set CVar [[r.TranslucencyLightingVolumeDim:64]]
# LogConfig: Set CVar [[r.RefractionQuality:2]]
# LogConfig: Set CVar [[r.SceneColorFormat:4]]
# LogConfig: Set CVar [[r.DetailMode:3]]
# LogConfig: Set CVar [[r.TranslucencyVolumeBlur:1]]
# LogConfig: Set CVar [[r.MaterialQualityLevel:1 ; High quality]]
# LogConfig: Set CVar [[r.SSS.Scale:1]]
# LogConfig: Set CVar [[r.SSS.SampleSet:2]]
# LogConfig: Set CVar [[r.SSS.Quality:1]]
# LogConfig: Set CVar [[r.SSS.HalfRes:0]]
# LogConfig: Set CVar [[r.SSGI.Quality:3]]
# LogConfig: Set CVar [[r.EmitterSpawnRateScale:1.0]]
# LogConfig: Set CVar [[r.ParticleLightQuality:2]]
# LogConfig: Set CVar [[r.SkyAtmosphere.AerialPerspectiveLUT.FastApplyOnOpaque:1 ; Always have FastSkyLUT 1 in this case to avoid wrong sky]]
# LogConfig: Set CVar [[r.SkyAtmosphere.AerialPerspectiveLUT.SampleCountMaxPerSlice:4]]
# LogConfig: Set CVar [[r.SkyAtmosphere.AerialPerspectiveLUT.DepthResolution:16.0]]
# LogConfig: Set CVar [[r.SkyAtmosphere.FastSkyLUT:1]]
# LogConfig: Set CVar [[r.SkyAtmosphere.FastSkyLUT.SampleCountMin:4.0]]
# LogConfig: Set CVar [[r.SkyAtmosphere.FastSkyLUT.SampleCountMax:128.0]]
# LogConfig: Set CVar [[r.SkyAtmosphere.SampleCountMin:4.0]]
# LogConfig: Set CVar [[r.SkyAtmosphere.SampleCountMax:128.0]]
# LogConfig: Set CVar [[r.SkyAtmosphere.TransmittanceLUT.UseSmallFormat:0]]
# LogConfig: Set CVar [[r.SkyAtmosphere.TransmittanceLUT.SampleCount:10.0]]
# LogConfig: Set CVar [[r.SkyAtmosphere.MultiScatteringLUT.SampleCount:15.0]]
# LogConfig: Set CVar [[fx.Niagara.QualityLevel:3]]
# LogConfig: Set CVar [[r.Refraction.OffsetQuality:1]]
# LogConfig: Set CVar [[r.HeterogeneousVolumes.DownsampleFactor:1]]
# LogConfig: Set CVar [[r.HeterogeneousVolumes.MaxStepCount:512]]
# LogConfig: Set CVar [[r.HeterogeneousVolumes.Shadows.Resolution:512]]
# LogConfig: Applying CVar settings from Section [FoliageQuality@3] File [Scalability]
# LogConfig: Set CVar [[foliage.DensityScale:1.0]]
# LogConfig: Set CVar [[grass.DensityScale:1.0]]
# LogConfig: Applying CVar settings from Section [ShadingQuality@3] File [Scalability]
# LogConfig: Set CVar [[r.HairStrands.SkyLighting.IntegrationType:2]]
# LogConfig: Set CVar [[r.HairStrands.SkyAO.SampleCount:4]]
# LogConfig: Set CVar [[r.HairStrands.Visibility.MSAA.SamplePerPixel:4]]
# LogConfig: Set CVar [[r.AnisotropicMaterials:1]]
# LogConfig: Applying CVar settings from Section [LandscapeQuality@3] File [Scalability]
# LogInit: Selected Device Profile: [Mac]
# LogInit: Selected Device Profile: [Mac]
# LogHAL: Display: Platform has ~ 128 GB [137438953472 / 137438953472 / 128], which maps to Largest [LargestMinGB=32, LargerMinGB=12, DefaultMinGB=8, SmallerMinGB=6, SmallestMinGB=0)
# LogDeviceProfileManager: Going up to parent DeviceProfile []
# LogDeviceProfileManager: Pushing Device Profile CVar: [[r.Shaders.ZeroInitialise:1 -> 1]]
# LogDeviceProfileManager: Pushing Device Profile CVar: [[r.Shaders.BoundsChecking:1 -> 1]]
# ...
# LogInit: Model: Mac15,9
# LogInit: CPU: Apple M3 Max
# LogInit: CPU Page size=16384, Cores=16, HT=16
# LogInit: Computer: Mac-1233.lan
# LogInit: User: miroberts
# LogInit: High frequency timer resolution =24.000000 MHz
# LogInit: Power Source: AC Power
# LogInit: Memory total: Physical=128.0GB (128GB approx) Pagefile=6.0GB Virtual=134.0GB
# LogCsvProfiler: Display: Metadata set : extradevelopmentmemorymb="0"
# LogChaosDD: Chaos Debug Draw Startup
# LogInit: Physics initialised using underlying interface: Chaos
# LogInit: Using OS detected language (en-US).
# LogInit: Using OS detected locale (en-US).
# LogTextLocalizationManager: No specific localization for 'en-US' exists, so 'en' will be used for the language.
# LogSlate: New Slate User Created. Platform User Id 0, User Index 0, Is Virtual User: 0
# LogSlate: Slate User Registered.  User Index 0, Is Virtual User: 0
# LogRHI: Texture pool is 68812 MB (70% of 98304 MB)
# LogMetal: Display:       Vendor ID: 4203
# LogMetal: Display:       Device ID: 909194570
# LogMetal: Display:       VRAM (MB): 98304
# LogRHI: RHI Adapter Info:
# LogRHI:             Name: Apple M3 Max
# LogRHI:   Driver Version:  (internal:320.35.5, unified:320.35.5)
# LogRHI:      Driver Date: 1-1-1970
# LogMetal: Display: Got a bulk data texture, with 1 mips
# LogMetal: Display: Got a bulk data texture, with 1 mips
# LogMetal: Display: Got a bulk data texture, with 1 mips
# LogMetal: Display: Got a bulk data texture, with 1 mips
# LogMetal: Display: Got a bulk data texture, with 1 mips
# LogMetal: Display: Got a bulk data texture, with 1 mips
# LogMetal: Display: Got a bulk data texture, with 1 mips
# LogVRS: Current RHI does not support Variable Rate Shading
# LogInit: Initializing FReadOnlyCVARCache
# LogRendererCore: Ray tracing is disabled. Reason: not supported by current RHI.
# LogInit: FStereoShaderAspects: --- StereoAspects begin ---
# LogInit: FStereoShaderAspects: Platform=METAL_SM5 (16)
# LogInit: FStereoShaderAspects: bInstancedStereo = 0
# LogInit: FStereoShaderAspects: bMobilePlatform = 0
# LogInit: FStereoShaderAspects: bMobilePostprocessing = 1
# LogInit: FStereoShaderAspects: bMobileMultiView = 0
# LogInit: FStereoShaderAspects: bMultiViewportCapable = 1
# LogInit: FStereoShaderAspects: bInstancedStereoNative = 0
# LogInit: FStereoShaderAspects: ---
# LogInit: FStereoShaderAspects: bMobileMultiViewCoreSupport = 0
# LogInit: FStereoShaderAspects: bMobileMultiViewNative = 0
# LogInit: FStereoShaderAspects: bMobileMultiViewFallback = 0
# LogInit: FStereoShaderAspects: ---
# LogInit: FStereoShaderAspects: bInstancedMultiViewportEnabled = 0
# LogInit: FStereoShaderAspects: bInstancedStereoEnabled = 0
# LogInit: FStereoShaderAspects: bMobileMultiViewEnabled = 0
# LogInit: FStereoShaderAspects: --- StereoAspects end ---
# LogSlate: Using FreeType 2.10.0
# LogSlate: SlateFontServices - WITH_FREETYPE: 1, WITH_HARFBUZZ: 1
# [SPEAR | instance.py:0447]         Attempting to connect to server...
# [SPEAR | spear_ext.cpp] Client::Client(...)
# [SPEAR | spear_ext.cpp] Client::terminate()
# [SPEAR | spear_ext.cpp] Client::~Client()
# LogInit: Using OS detected language (en-US).
# LogInit: Using OS detected locale (en-US).
# LogTextLocalizationManager: No localization for 'en-US' exists, so 'en' will be used for the language.
# LogTextLocalizationManager: No localization for 'en-US' exists, so 'en' will be used for the locale.
# LogSlate: FontCache flush requested. Reason: Culture for localization was changed
# LogSlate: FontCache flush requested. Reason: Culture for localization was changed
# LogAssetRegistry: FAssetRegistry took 0.0001 seconds to start up
# LogStreaming: Display: FlushAsyncLoading(1): 1 QueuedPackages, 0 AsyncPackages
# LogDeviceProfileManager: Display: Deviceprofile LinuxArm64Editor not found.
# LogDeviceProfileManager: Display: Deviceprofile LinuxArm64 not found.
# LogInit: Selected Device Profile: [Mac]
# LogDeviceProfileManager: Active device profile: [0x3007c06b8][0x32edc8040 66] Mac
# LogCsvProfiler: Display: Metadata set : deviceprofile="Mac"
# LogConfig: Branch 'EditorPerProjectUserSettings' had been unloaded. Reloading on-demand took 0.05ms
# LogPackageLocalizationCache: Processed 68 localized package path(s) for 1 prioritized culture(s) in 0.000301 seconds
# LogConfig: Branch 'GameplayTagsList' had been unloaded. Reloading on-demand took 0.04ms
# LogConfig: Branch 'TranslationPickerSettings' had been unloaded. Reloading on-demand took 0.05ms
# LogConfig: Branch 'Mass' had been unloaded. Reloading on-demand took 0.04ms
# [SPEAR | SpStableNameManager.cpp:0245] USpStableNameEventHandler::USpStableNameEventHandler()
# [SPEAR | SpDummyActor.cpp:0012] ASpDummyActor::ASpDummyActor()
# LogAudioCaptureCore: Display: No Audio Capture implementations found. Audio input will be silent.
# LogAudioCaptureCore: Display: No Audio Capture implementations found. Audio input will be silent.
# [SPEAR | SpDebugManager.cpp:0057] ASpDebugManager::ASpDebugManager()
# [SPEAR | SpDebugManager.cpp:0078] ASpDebugManager::PostInitProperties()
# [SPEAR | SpBasicKeyboardControlComponent.cpp:0027] USpBasicKeyboardControlComponent::USpBasicKeyboardControlComponent()
# [SPEAR | SpUserInputComponent.cpp:0026] USpUserInputComponent::USpUserInputComponent()
# [SPEAR | SpUserInputComponent.cpp:0026] USpUserInputComponent::USpUserInputComponent()
# [SPEAR | SpProxyComponentManager.cpp:0040] ASpProxyComponentManager::ASpProxyComponentManager()
# [SPEAR | SpProxyComponentManager.cpp:0040] ASpProxyComponentManager::ASpProxyComponentManager()
# [SPEAR | SpProxyComponentManager.cpp:0040] ASpProxyComponentManager::ASpProxyComponentManager()
# [SPEAR | SpProxyComponentManager.cpp:0040] ASpProxyComponentManager::ASpProxyComponentManager()
# [SPEAR | SpGameMode.cpp:0039] ASpGameMode::ASpGameMode()
# [SPEAR | SpUpdateTransformComponent.h:0032] USpUpdateTransformComponent::USpUpdateTransformComponent()
# [SPEAR | SpDummyComponent.h:0040] USpDummyComponent::USpDummyComponent()
# [SPEAR | SpUserInputComponent.cpp:0026] USpUserInputComponent::USpUserInputComponent()
# [SPEAR | SpInitializeWorldManager.cpp:0027] ASpInitializeWorldManager::ASpInitializeWorldManager()
# [SPEAR | SpDebugCameraController.cpp:0017] ASpDebugCameraController::ASpDebugCameraController()
# [SPEAR | SpPlayerController.cpp:0020] ASpPlayerController::ASpPlayerController()
# [SPEAR | SpUserInputComponent.cpp:0026] USpUserInputComponent::USpUserInputComponent()
# [SPEAR | SpSceneCaptureComponent2D.cpp:0137] USpSceneCaptureComponent2D::USpSceneCaptureComponent2D()
# [SPEAR | SpActorHitManager.cpp:0026] ASpActorHitManager::ASpActorHitManager()
# [SPEAR | SpMoviePipelineDeferredPass.h:0042] USpMoviePipelineDeferredPass::USpMoviePipelineDeferredPass()
# [SPEAR | SpMoviePipelineDeferredPass.h:0042] USpMoviePipelineDeferredPass::USpMoviePipelineDeferredPass()
# [SPEAR | SpMoviePipelineDeferredPass.h:0146] USpMoviePipelineDeferredPass_ExtraPass0::USpMoviePipelineDeferredPass_ExtraPass0()
# [SPEAR | SpMoviePipelineDeferredPass.h:0042] USpMoviePipelineDeferredPass::USpMoviePipelineDeferredPass()
# [SPEAR | SpMoviePipelineDeferredPass.h:0158] USpMoviePipelineDeferredPass_ExtraPass1::USpMoviePipelineDeferredPass_ExtraPass1()
# [SPEAR | SpMoviePipelineDeferredPass.h:0042] USpMoviePipelineDeferredPass::USpMoviePipelineDeferredPass()
# [SPEAR | SpMoviePipelineDeferredPass.h:0170] USpMoviePipelineDeferredPass_ExtraPass2::USpMoviePipelineDeferredPass_ExtraPass2()
# [SPEAR | SpMoviePipelineDeferredPass.h:0042] USpMoviePipelineDeferredPass::USpMoviePipelineDeferredPass()
# [SPEAR | SpMoviePipelineDeferredPass.h:0182] USpMoviePipelineDeferredPass_ExtraPass3::USpMoviePipelineDeferredPass_ExtraPass3()
# [SPEAR | SpPauseManager.h:0025] ASpPauseManager::ASpPauseManager()
# [SPEAR | SpSpectatorPawn.cpp:0028] ASpSpectatorPawn::ASpSpectatorPawn()
# LogConfig: Applying CVar settings from Section [/Script/NNEDenoiser.NNEDenoiserSettings] File [Engine]
# LogMetaSound: Display: MetaSound Page Target Initialized to 'Default'
# LogMoviePlayer: FAVMoviePlayer ctor...
# LogMoviePlayer: Initializing movie player
# LogInit: XR: Instanced Stereo Rendering is Disabled
# LogInit: XR: MultiViewport is Disabled
# LogInit: XR: Mobile Multiview is Disabled
# LogNiagaraDebuggerClient: Niagara Debugger Client Initialized | Session: D4026609E8F94AEC8000000000007A00 | Instance: 39B451BAA44F3F059E817C85793479E6 (Mac-1233.lan-92661).
# LogAudio: Display: Registering Engine Module Parameter Interfaces...
# 2025-12-31 00:05:41.309 SpearSim[92661:28105845] +[IMKClient subclass]: chose IMKClient_Legacy
# 2025-12-31 00:05:41.309 SpearSim[92661:28105845] +[IMKInputSession subclass]: chose IMKInputSession_Legacy
# LogMetaSound: MetaSound Engine Initialized
# [SPEAR | SpearSim.cpp:0016] SpearSim::StartupModule()
# LogAndroidPermission: UAndroidPermissionCallbackProxy::GetInstance
# [SPEAR | SpServices.cpp:0045] SpServices::StartupModule()
# [SPEAR | RpcService.h:0022] RpcService::RpcService()
# [SPEAR | RpcService.h:0023]     Creating RPC server...
# [SPEAR | InitializeEngineService.h:0033] InitializeEngineService::InitializeEngineService()
# [SPEAR | InitializeEngineService.h:0113]     Overriding benchmarking...
# [SPEAR | InitializeEngineService.h:0114]     Old benchmarking: 0
# [SPEAR | InitializeEngineService.h:0118]     New benchmarking: 1
# [SPEAR | InitializeEngineService.h:0124]     Overriding fixed delta time...
# [SPEAR | InitializeEngineService.h:0125]     Old fixed delta time: 0.033333333333333333
# [SPEAR | InitializeEngineService.h:0129]     New fixed delta time: 0.033332999795675278
# [SPEAR | SpUnrealTypes.cpp:0016] SpUnrealTypes::StartupModule()
# LogUObjectArray: 28616 objects as part of root set at end of initial load.
# LogUObjectArray: 4 objects are not in the root set, but can never be destroyed because they are in the DisregardForGC set.
# LogUObjectArray: CloseDisregardForGC: 28616/28616 objects in disregard for GC pool
# LogStreaming: Display: AsyncLoading2 - NotifyRegistrationComplete: Registered 27901 public script object entries (771.99 KB)
# LogStreaming: Display: AsyncLoading2 - Thread Started: true, IsInitialLoad: false
# LogEngine: Initializing Engine...
# LogStats: UGameplayTagsManager::InitializeManager -  0.000 s
# LogNetVersion: Set ProjectVersion to 1.0.0.0. Version Checksum will be recalculated on next use.
# LogInit: Texture streaming: Enabled
# LogCsvProfiler: Display: Metadata set : largeworldcoordinates="1"
# LogChaosDD: Creating Chaos Debug Draw Scene for world Untitled
# LogRenderer: SceneCulling instance hierarchy is disabled as UseNanite(METAL_SM5) returned false, for scene: 'World /Temp/Untitled_0.Untitled'.
# LogSlate: Updating window title bar state: overlay mode, drag disabled, window buttons hidden, title bar hidden
# LogInit: Display: Game Engine Initialized.
# [SPEAR | InitializeEngineService.h:0184] InitializeEngineService::postEngineInit()
# LogNNEDenoiser: Ray Tracing is not enabled, therefore NNEDenoiser is not registered!
# LogInit: Display: Starting Game.
# LogGlobalStatus: Browse Started Browse: "/Game/SPEAR/Scenes/apartment_0000/Maps/apartment_0000?Name=Player"
# LogNet: Browse: /Game/SPEAR/Scenes/apartment_0000/Maps/apartment_0000?Name=Player
# LogLoad: LoadMap: /Game/SPEAR/Scenes/apartment_0000/Maps/apartment_0000?Name=Player
# LogWorld: BeginTearingDown for /Temp/Untitled_0
# LogWorld: UWorld::CleanupWorld for Untitled, bSessionEnded=true, bCleanupResources=true
# LogSlate: InvalidateAllWidgets triggered.  All widgets were invalidated
# LogUObjectHash: Compacting FUObjectHashTables data took   0.10ms
# LogChaosDD: Creating Chaos Debug Draw Scene for world apartment_0000
# LogRenderer: SceneCulling instance hierarchy is disabled as UseNanite(METAL_SM5) returned false, for scene: 'World /Game/SPEAR/Scenes/apartment_0000/Maps/apartment_0000.apartment_0000'.
# [SPEAR | InitializeGameWorldService.h:0040] InitializeGameWorldService::postWorldInitialization(...)
# LogLoad: Game class is 'SpGameMode'
# [SPEAR | SpGameMode.cpp:0039] ASpGameMode::ASpGameMode()
# LogWorld: Bringing World /Game/SPEAR/Scenes/apartment_0000/Maps/apartment_0000.apartment_0000 up for play (max tick rate 0) at 2025.12.31-00.05.41
# LogWorld: Bringing up level for play took: 0.004413
# [SPEAR | SpPlayerController.cpp:0020] ASpPlayerController::ASpPlayerController()
# [SPEAR | SpUserInputComponent.cpp:0026] USpUserInputComponent::USpUserInputComponent()
# [SPEAR | SpGameMode.cpp:0052] ASpGameMode::PostLogin(...)
# [SPEAR | SpSpectatorPawn.cpp:0028] ASpSpectatorPawn::ASpSpectatorPawn()
# [SPEAR | SpDebugCameraController.cpp:0017] ASpDebugCameraController::ASpDebugCameraController()
# [SPEAR | SpPlayerController.cpp:0045] ASpPlayerController::BeginPlay()
# [SPEAR | SpSpectatorPawn.cpp:0062] ASpSpectatorPawn::BeginPlay()
# [SPEAR | InitializeGameWorldService.h:0070] InitializeGameWorldService::worldBeginPlay()
# [SPEAR | InitializeGameWorldService.h:0081]     Overriding game paused...
# [SPEAR | InitializeGameWorldService.h:0082]     Old game paused: 0
# [SPEAR | InitializeGameWorldService.h:0083]     New game paused: 1
# [SPEAR | InitializeGameWorldService.h:0119]     Forcing skylight updates every frame for 1 seconds...
# [SPEAR | InitializeGameWorldService.h:0126]     Old value of r.SkylightUpdateEveryFrame: 0
# [SPEAR | InitializeGameWorldService.h:0127]     New value of r.SkylightUpdateEveryFrame: 1
# LogLoad: Took 0.415671 seconds to LoadMap(/Game/SPEAR/Scenes/apartment_0000/Maps/apartment_0000)
# LogGlobalStatus: LoadMap Load map complete /Game/SPEAR/Scenes/apartment_0000/Maps/apartment_0000
# LogSlate: Took 0.000520 seconds to synchronously load lazily loaded font '../../../Engine/Content/Slate/Fonts/Roboto-Regular.ttf' (155K)
# LogInit: Display: Engine is initialized. Leaving FEngineLoop::Init()
# LogLoad: (Engine Initialization) Total time: 1.71 seconds
# [SPEAR | RpcService.h:0069] RpcService::beginFrame()
# [SPEAR | RpcService.h:0070]     Launching RPC server...
# LogContentStreaming: Texture pool size now 1000 MB
# LogCsvProfiler: Display: Metadata set : streamingpoolsizemb="1000"
# LogSlate: InvalidateAllWidgets triggered.  All widgets were invalidated
# [SPEAR | instance.py:0447]         Attempting to connect to server...
# [SPEAR | spear_ext.cpp] Client::Client(...)
# [SPEAR | instance.py:0466]         Connected to server.
# [SPEAR | instance.py:0477]         Validated engine_globals_service.call_sync_on_worker_thread.get_id: 92661
# [SPEAR | instance.py:0490]         Finished initializing client.
# [SPEAR | instance.py:0495]     _validate_client_and_server_entry_points
# LogSlate: Slate font cache was flushed
# LogSlate: InvalidateAllWidgets triggered.  All widgets were invalidated
# LogTrace: Display: Display Control listening on port 1985
# LogSlate: Took 0.000073 seconds to synchronously load lazily loaded font '../../../Engine/Content/Slate/Fonts/Roboto-Regular.ttf' (155K)
# [SPEAR | instance.py:0496]         Validating client and server entry points...
# [SPEAR | instance.py:0582]         Finished validating client and server entry points.
# [SPEAR | instance.py:0177] get_game
# [SPEAR | instance.py:0587]     _wait_until
# [SPEAR | instance.py:0588]         Waiting for function to return true: <bound method InitializeWorldService.is_initialized of <spear.services.initialize_world_service.InitializeWorldService object at 0x117276410>>
# [SPEAR | instance.py:0591]         Waiting for up to 5.0 seconds, retrying every 1.0 seconds...
# [SPEAR | InitializeGameWorldService.h:0146] InitializeGameWorldService::beginFrame()
# [SPEAR | InitializeGameWorldService.h:0147]     Setting r.SkylightUpdateEveryFrame: 0
# [SPEAR | InitializeGameWorldService.h:0158]     Finished initializing.
# [SPEAR | instance.py:0610]         Finished waiting for function to return true.
# [SPEAR | instance.py:0615]     _request_warm_up_unreal_instance
# [SPEAR | instance.py:0616]         Requesting to warm up Unreal instance...
# [SPEAR | instance.py:0631]         _warm_up_unreal_instance
# [SPEAR | instance.py:0632]             Warming up Unreal instance for 5.0 seconds and 1 frames...
# [SPEAR | instance.py:0640]             Finished warming up Unreal instance.
# [SPEAR | instance.py:0626]         Finished requesting to warm up Unreal instance.
# [SPEAR | instance.py:0198]     Initializing game-scoped services...
# [SPEAR | instance.py:0203]     Finished initializing game-scoped services.

# %%
with instance.begin_frame():

    # spawn object
    bp_axes_uclass = game.unreal_service.load_class(uclass="AActor", name="/SpContent/Blueprints/BP_Axes.BP_Axes_C")
    bp_axes = game.unreal_service.spawn_actor(uclass=bp_axes_uclass, location={"X": -10.0, "Y": 280.0, "Z": 50.0})

    # get all object properties
    spear.log("bp_axes: ", bp_axes)
    spear.log("bp_axes.get_properties():")
    pprint.pprint(bp_axes.get_properties())

    # get scale
    scale = bp_axes.GetActorScale3D()
    spear.log("scale: ", scale)

    # set scale and get it again to verify that it has been updated
    bp_axes.SetActorScale3D(NewScale3D={"X": 4.0, "Y": 4.0, "Z": 4.0})
    scale = bp_axes.GetActorScale3D()
    spear.log("scale: ", scale)

    # access object properties on the root component of bp_axes
    root_component = bp_axes.RootComponent.get()
    spear.log("root_component: ", root_component)
    spear.log("root_component.get_properties():")
    pprint.pprint(root_component.get_properties())

with instance.end_frame():
    pass

spear.log("Done.")
# Out:
# LogStreaming: Display: FlushAsyncLoading(73): 1 QueuedPackages, 0 AsyncPackages
# [SPEAR | 752151075.py:0008] bp_axes: UnrealObject(uobject=16022492816, uclass=14178737376, property_name="", _is_top_level=True, _static_class_desc=spear_ext.StaticStructDesc(name='BP_Axes_C', static_struct=14178737376, ufunctions=147), _initialized_sp_funcs=False, _sp_func_names=None)
# [SPEAR | 752151075.py:0009] bp_axes.get_properties():
# {'autoReceiveInput': 'Disabled',
#  'bActorEnableCollision': True,
#  'bAllowReceiveTickEventOnDedicatedServer': True,
#  'bAllowTickBeforeBeginPlay': False,
#  'bAlwaysRelevant': False,
#  'bAsyncPhysicsTickEnabled': False,
#  'bAutoDestroyWhenFinished': False,
#  'bBlockInput': False,
#  'bCallPreReplication': True,
#  'bCallPreReplicationForReplay': True,
#  'bCanBeDamaged': True,
#  'bCanBeInCluster': False,
#  'bCollideWhenPlacing': False,
#  'bEnableAutoLODGeneration': True,
#  'bFindCameraComponentWhenViewTarget': True,
#  'bForceNetAddressable': False,
#  'bGenerateOverlapEventsDuringLevelStreaming': False,
#  'bHidden': False,
#  'bIgnoresOriginShifting': False,
#  'bIsEditorOnlyActor': False,
#  'bNetLoadOnClient': True,
#  'bNetTemporary': False,
#  'bNetUseOwnerRelevancy': False,
#  'bOnlyRelevantToOwner': False,
#  'bRelevantForLevelBounds': True,
#  'bRelevantForNetworkReplays': True,
#  'bReplayRewindable': False,
#  'bReplicateMovement': False,
#  'bReplicateUsingRegisteredSubObjectList': False,
#  'bReplicates': False,
#  'bTearOff': False,
#  'blueprintCreatedComponents': ["/Script/Engine.SceneComponent'/Game/SPEAR/Scenes/apartment_0000/Maps/apartment_0000.apartment_0000:PersistentLevel.BP_Axes_C_2147482454.DefaultSceneRoot'",
#                                 "/Script/Engine.StaticMeshComponent'/Game/SPEAR/Scenes/apartment_0000/Maps/apartment_0000.apartment_0000:PersistentLevel.BP_Axes_C_2147482454.origin_'",
#                                 "/Script/Engine.StaticMeshComponent'/Game/SPEAR/Scenes/apartment_0000/Maps/apartment_0000.apartment_0000:PersistentLevel.BP_Axes_C_2147482454.x_axis_'",
#                                 "/Script/Engine.StaticMeshComponent'/Game/SPEAR/Scenes/apartment_0000/Maps/apartment_0000.apartment_0000:PersistentLevel.BP_Axes_C_2147482454.y_axis_'",
#                                 "/Script/Engine.StaticMeshComponent'/Game/SPEAR/Scenes/apartment_0000/Maps/apartment_0000.apartment_0000:PersistentLevel.BP_Axes_C_2147482454.z_axis_'",
#                                 "/Script/SpCore.SpStableNameComponent'/Game/SPEAR/Scenes/apartment_0000/Maps/apartment_0000.apartment_0000:PersistentLevel.BP_Axes_C_2147482454.sp_stable_name_component_'"],
#  'customTimeDilation': 1,
#  'defaultSceneRoot': "/Script/Engine.SceneComponent'/Game/SPEAR/Scenes/apartment_0000/Maps/apartment_0000.apartment_0000:PersistentLevel.BP_Axes_C_2147482454.DefaultSceneRoot'",
#  'defaultUpdateOverlapsMethodDuringLevelStreaming': 'OnlyUpdateMovable',
#  'initialLifeSpan': 0,
#  'inputComponent': 'None',
#  'inputPriority': 0,
#  'instanceComponents': [],
#  'instigator': 'None',
#  'layers': [],
#  'minNetUpdateFrequency': 2,
#  'netCullDistanceSquared': 225000000,
#  'netDormancy': 'DORM_Awake',
#  'netDriverName': 'GameNetDriver',
#  'netPriority': 1,
#  'netUpdateFrequency': 100,
#  'onActorBeginOverlap': '()',
#  'onActorEndOverlap': '()',
#  'onActorHit': '()',
#  'onBeginCursorOver': '()',
#  'onClicked': '()',
#  'onDestroyed': '()',
#  'onEndCursorOver': '()',
#  'onEndPlay': '()',
#  'onInputTouchBegin': '()',
#  'onInputTouchEnd': '()',
#  'onInputTouchEnter': '()',
#  'onInputTouchLeave': '()',
#  'onReleased': '()',
#  'onTakeAnyDamage': '()',
#  'onTakePointDamage': '()',
#  'onTakeRadialDamage': '()',
#  'origin_': "/Script/Engine.StaticMeshComponent'/Game/SPEAR/Scenes/apartment_0000/Maps/apartment_0000.apartment_0000:PersistentLevel.BP_Axes_C_2147482454.origin_'",
#  'owner': 'None',
#  'parentComponent': 'None',
#  'physicsReplicationMode': 'Default',
#  'primaryActorTick': {'bAllowTickOnDedicatedServer': True,
#                       'bCanEverTick': False,
#                       'bStartWithTickEnabled': True,
#                       'bTickEvenWhenPaused': False,
#                       'endTickGroup': 'TG_PrePhysics',
#                       'tickGroup': 'TG_PrePhysics',
#                       'tickInterval': 0},
#  'rayTracingGroupId': -1,
#  'replicatedMovement': {'locationQuantizationLevel': 'RoundWholeNumber',
#                         'rotationQuantizationLevel': 'ByteComponents',
#                         'velocityQuantizationLevel': 'RoundWholeNumber'},
#  'role': 'ROLE_Authority',
#  'rootComponent': "/Script/Engine.SceneComponent'/Game/SPEAR/Scenes/apartment_0000/Maps/apartment_0000.apartment_0000:PersistentLevel.BP_Axes_C_2147482454.DefaultSceneRoot'",
#  'sp_stable_name_component_': "/Script/SpCore.SpStableNameComponent'/Game/SPEAR/Scenes/apartment_0000/Maps/apartment_0000.apartment_0000:PersistentLevel.BP_Axes_C_2147482454.sp_stable_name_component_'",
#  'spawnCollisionHandlingMethod': 'AlwaysSpawn',
#  'tags': [],
#  'updateOverlapsMethodDuringLevelStreaming': 'UseConfigDefault',
#  'x_axis_': "/Script/Engine.StaticMeshComponent'/Game/SPEAR/Scenes/apartment_0000/Maps/apartment_0000.apartment_0000:PersistentLevel.BP_Axes_C_2147482454.x_axis_'",
#  'y_axis_': "/Script/Engine.StaticMeshComponent'/Game/SPEAR/Scenes/apartment_0000/Maps/apartment_0000.apartment_0000:PersistentLevel.BP_Axes_C_2147482454.y_axis_'",
#  'z_axis_': "/Script/Engine.StaticMeshComponent'/Game/SPEAR/Scenes/apartment_0000/Maps/apartment_0000.apartment_0000:PersistentLevel.BP_Axes_C_2147482454.z_axis_'"}
# [SPEAR | 752151075.py:0014] scale: {'x': 1, 'y': 1, 'z': 1}
# [SPEAR | 752151075.py:0019] scale: {'x': 4, 'y': 4, 'z': 4}
# [SPEAR | 752151075.py:0023] root_component: UnrealObject(uobject=14290348864, uclass=12885144704, property_name="", _is_top_level=True, _static_class_desc=spear_ext.StaticStructDesc(name='USceneComponent', static_struct=12885144704, ufunctions=92), _initialized_sp_funcs=False, _sp_func_names=None)
# [SPEAR | 752151075.py:0024] root_component.get_properties():
# {'assetUserData': [],
#  'attachParent': 'None',
#  'attachSocketName': 'None',
#  'bAbsoluteLocation': False,
#  'bAbsoluteRotation': False,
#  'bAbsoluteScale': False,
#  'bAutoActivate': False,
#  'bBoundsChangeTriggersStreamingDataRebuild': False,
#  'bCanEverAffectNavigation': False,
#  'bComputeBoundsOnceForGame': False,
#  'bComputeFastLocalBounds': False,
#  'bComputedBoundsOnceForGame': False,
#  'bEditableWhenInherited': True,
#  'bHiddenInGame': False,
#  'bIsEditorOnly': False,
#  'bIsNotRenderAttachmentRoot': False,
#  'bNetAddressable': True,
#  'bReplicateUsingRegisteredSubObjectList': False,
#  'bReplicates': False,
#  'bShouldUpdatePhysicsVolume': False,
#  'bUseAttachParentBound': False,
#  'bVisible': True,
#  'componentTags': [],
#  'componentVelocity': {'x': 0, 'y': 0, 'z': 0},
#  'creationMethod': 'SimpleConstructionScript',
#  'detailMode': 'DM_Low',
#  'mobility': 'Movable',
#  'onComponentActivated': '()',
#  'onComponentDeactivated': '()',
#  'physicsVolumeChangedDelegate': '()',
#  'primaryComponentTick': {'bAllowTickOnDedicatedServer': True,
#                           'bCanEverTick': False,
#                           'bStartWithTickEnabled': True,
#                           'bTickEvenWhenPaused': False,
#                           'endTickGroup': 'TG_PrePhysics',
#                           'tickGroup': 'TG_DuringPhysics',
#                           'tickInterval': 0},
#  'relativeLocation': {'x': -10, 'y': 280, 'z': 50},
#  'relativeRotation': {'pitch': 0, 'roll': 0, 'yaw': 0},
#  'relativeScale3D': {'x': 4, 'y': 4, 'z': 4},
#  'uCSSerializationIndex': 0}
# [SPEAR | 752151075.py:0030] Done.
